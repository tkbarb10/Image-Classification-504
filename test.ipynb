# %%
import pandas as pd

# %%
df = pd.read_parquet("C:/Users/tkbar/ADS_504_Image_Project/Project/open_image_bytes.parquet")

# %%
import io
import ast
from PIL import Image

# 1. Your byte string (example: loaded from a file or API)
byte_data = df.iloc[0]['image_bytes']
real_bytes = ast.literal_eval(byte_data)

# 2. Wrap bytes in a BytesIO object
image_stream = io.BytesIO(real_bytes)

# 3. Open as an image
img = Image.open(image_stream)

# Now you can show it or process it
img.show()
print(img.format, img.size)
# Out:
# JPEG (1024, 859)

# %%
df = pd.read_parquet("C:/Users/tkbar/ADS_504_Image_Project/Project/extra_images.parquet")

# %%
df.head()
# Out:
#                                                bytes  label original_dataset
# 0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...      0       ai_v_human
# 1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...      1      open_images
# 2  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...      1      open_images
# 3  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...      1      open_images
# 4  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...      1       ai_v_human

# %%
array = np.load("C:/Users/tkbar/ADS/ADS504-Final/data/arrays/test/image_01245.npy")

# %%
import matplotlib.pyplot as plt
from config.paths import ARRAYS_DIR
import glob

# %%
file_paths = sorted(glob.glob(str(ARRAYS_DIR / "test" / "image_*.npy")))
arrays = [np.load(fp) for fp in file_paths]

# %%
plt.imshow(arrays[1224])

# %%
df = pd.read_parquet("C:/Users/tkbar/ADS/ADS504-Final/data/metadata/test_metadata.parquet")
